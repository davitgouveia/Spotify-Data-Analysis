# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Dataframe das Músicas

# %% [markdown]
# ## Importando as bibliotecas

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Juntando os arquivos dos dataframes

# %%
diretorio = "./DataFrames/Musicas"
arquivos = [arquivo for arquivo in os.listdir(diretorio) if not arquivo.startswith('.')] #Ignora arquivos escondidos

df_musicas = pd.DataFrame()

for arquivo in arquivos:
    data_atual = pd.read_csv(diretorio+"/"+arquivo)
    df_musicas = pd.concat([df_musicas, data_atual])

# %%
df_musicas.head()
# Out:
#    Unnamed: 0                track_id             track_name  artist_name  \
# 0           0  4uqJelb9THHmJ3OCohg4ZJ           Nosso Quadro  Ana Castela
# 1           1  0SCMVUZ21uYYB8cc0ScfbV  Bombonzinho - Ao Vivo  Ana Castela
# 2           2  0redQHBfejmPUhonR5ppGC              Duas Três  Ana Castela
# 3           3  7sopDXkuzXtHt8AQpdBxmT            DONA DE MIM  Ana Castela
# 4           4  5y7yYXNSsT89A27DQxbmUL               Covardia  Ana Castela
#
#                               artist_genres                    album_name  \
# 0  ['agronejo', 'funk rj', 'sertanejo pop']                  Nosso Quadro
# 1  ['agronejo', 'funk rj', 'sertanejo pop']  Let's Bora, Vol. 2 (Ao Vivo)
# 2  ['agronejo', 'funk rj', 'sertanejo pop']                     Duas Três
# 3  ['agronejo', 'funk rj', 'sertanejo pop']                   DONA DE MIM
# 4  ['agronejo', 'funk rj', 'sertanejo pop']                      Covardia
#
#                 artist_id  popularity  duration_ms  explicit  ...  key  \
# 0  2CKOmarVWvWqkNWUatHCex          84       173698     False  ...    9
# 1  2CKOmarVWvWqkNWUatHCex          79       154701     False  ...    1
# 2  2CKOmarVWvWqkNWUatHCex          87       156942     False  ...    5
# 3  2CKOmarVWvWqkNWUatHCex          84       145091     False  ...    1
# 4  2CKOmarVWvWqkNWUatHCex          84       150863     False  ...    8
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -4.821     1       0.1950         0.338               0.0    0.3110
# 1    -3.672     1       0.0548         0.300               0.0    0.9200
# 2    -3.746     0       0.2010         0.574               0.0    0.6890
# 3    -4.726     1       0.2340         0.437               0.0    0.1100
# 4    -3.316     1       0.0522         0.215               0.0    0.0827
#
#    valence    tempo  time_signature
# 0    0.602  160.018               4
# 1    0.706  158.054               4
# 2    0.721  159.918               4
# 3    0.728  167.922               4
# 4    0.745  149.969               4
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Análise exploratória de dados

# %% [markdown]
# ### Informações sobre as colunas

# %%
df_musicas.shape
# Out:
# (8168, 22)

# %%
df_musicas.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'track_name', 'artist_name', 'artist_genres',
#        'album_name', 'artist_id', 'popularity', 'duration_ms', 'explicit',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature'],
#       dtype='object')

# %%
df_musicas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8168 entries, 0 to 494
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        8168 non-null   int64
#  1   track_id          8168 non-null   object
#  2   track_name        8168 non-null   object
#  3   artist_name       8168 non-null   object
#  4   artist_genres     8168 non-null   object
#  5   album_name        8168 non-null   object
#  6   artist_id         8168 non-null   object
#  7   popularity        8168 non-null   int64
#  8   duration_ms       8168 non-null   int64
#  9   explicit          8168 non-null   bool
#  10  danceability      8168 non-null   float64
#  11  energy            8168 non-null   float64
#  12  key               8168 non-null   int64
#  13  loudness          8168 non-null   float64
#  14  mode              8168 non-null   int64
#  15  speechiness       8168 non-null   float64
#  16  acousticness      8168 non-null   float64
#  17  instrumentalness  8168 non-null   float64
#  18  liveness          8168 non-null   float64
#  19  valence           8168 non-null   float64
#  20  tempo             8168 non-null   float64
#  21  time_signature    8168 non-null   int64
# dtypes: bool(1), float64(9), int64(6), object(6)
# memory usage: 1.4+ MB

# %%
df_musicas.dtypes
# Out:
# Unnamed: 0            int64
# track_id             object
# track_name           object
# artist_name          object
# artist_genres        object
# album_name           object
# artist_id            object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# dtype: object

# %%
df_musicas.dtypes.value_counts()
# Out:
# float64    9
# int64      6
# object     6
# bool       1
# dtype: int64

# %% [markdown]
# ### Análise estatísticas

# %%
df_musicas.describe()
# Out:
#         Unnamed: 0   popularity   duration_ms  danceability       energy  \
# count  8168.000000  8168.000000  8.168000e+03   8168.000000  8168.000000
# mean    264.611900    61.193193  2.146404e+05      0.658569     0.643423
# std     187.585059    14.593480  9.381802e+04      0.153078     0.186913
# min       0.000000     0.000000  3.200000e+04      0.000000     0.000019
# 25%     117.000000    53.000000  1.630888e+05      0.564000     0.516000
# 50%     245.000000    62.000000  1.953245e+05      0.671000     0.660500
# 75%     377.000000    71.000000  2.366090e+05      0.766000     0.787000
# max     999.000000    98.000000  1.831455e+06      0.985000     1.000000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  8168.000000  8168.000000  8168.000000  8168.000000   8168.000000
# mean      5.370470    -6.621769     0.560113     0.125688      0.351054
# std       3.583033     3.583904     0.496404     0.128899      0.265169
# min       0.000000   -39.482000     0.000000     0.000000      0.000000
# 25%       2.000000    -8.150000     0.000000     0.039700      0.110000
# 50%       5.000000    -6.046000     1.000000     0.064350      0.314000
# 75%       9.000000    -4.374000     1.000000     0.168000      0.569000
# max      11.000000     3.064000     1.000000     0.930000      0.995000
#
#        instrumentalness     liveness      valence        tempo  time_signature
# count       8168.000000  8168.000000  8168.000000  8168.000000     8168.000000
# mean           0.025229     0.241157     0.566044   122.959538        3.989349
# std            0.129112     0.231005     0.228335    27.048050        0.379800
# min            0.000000     0.000000     0.000000     0.000000        0.000000
# 25%            0.000000     0.099475     0.394000   102.025000        4.000000
# 50%            0.000000     0.136000     0.581000   124.948000        4.000000
# 75%            0.000032     0.295000     0.746000   139.878500        4.000000
# max            0.999000     0.993000     0.981000   208.500000        5.000000

# %% [markdown]
# ### Verificando se existem valores nulos no dataframe

# %%
df_musicas.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# track_name          0
# artist_name         0
# artist_genres       0
# album_name          0
# artist_id           0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %% [markdown]
# ### Verificando se existem linhas duplicadas no dataframe

# %%
df_musicas.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 490    False
# 491    False
# 492    False
# 493    False
# 494    False
# Length: 8168, dtype: bool

# %%
df_musicas.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Tratando o dataframe

# %% [markdown]
# ### Excluindo a coluna "Unnamed: 0"

# %%
df_musicas = df_musicas.drop("Unnamed: 0", axis=1)
df_musicas.head()
# Out:
#                  track_id             track_name  artist_name  \
# 0  4uqJelb9THHmJ3OCohg4ZJ           Nosso Quadro  Ana Castela
# 1  0SCMVUZ21uYYB8cc0ScfbV  Bombonzinho - Ao Vivo  Ana Castela
# 2  0redQHBfejmPUhonR5ppGC              Duas Três  Ana Castela
# 3  7sopDXkuzXtHt8AQpdBxmT            DONA DE MIM  Ana Castela
# 4  5y7yYXNSsT89A27DQxbmUL               Covardia  Ana Castela
#
#                               artist_genres                    album_name  \
# 0  ['agronejo', 'funk rj', 'sertanejo pop']                  Nosso Quadro
# 1  ['agronejo', 'funk rj', 'sertanejo pop']  Let's Bora, Vol. 2 (Ao Vivo)
# 2  ['agronejo', 'funk rj', 'sertanejo pop']                     Duas Três
# 3  ['agronejo', 'funk rj', 'sertanejo pop']                   DONA DE MIM
# 4  ['agronejo', 'funk rj', 'sertanejo pop']                      Covardia
#
#                 artist_id  popularity  duration_ms  explicit  danceability  \
# 0  2CKOmarVWvWqkNWUatHCex          84       173698     False         0.691
# 1  2CKOmarVWvWqkNWUatHCex          79       154701     False         0.654
# 2  2CKOmarVWvWqkNWUatHCex          87       156942     False         0.656
# 3  2CKOmarVWvWqkNWUatHCex          84       145091     False         0.680
# 4  2CKOmarVWvWqkNWUatHCex          84       150863     False         0.656
#
#    ...  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0  ...    9    -4.821     1       0.1950         0.338               0.0
# 1  ...    1    -3.672     1       0.0548         0.300               0.0
# 2  ...    5    -3.746     0       0.2010         0.574               0.0
# 3  ...    1    -4.726     1       0.2340         0.437               0.0
# 4  ...    8    -3.316     1       0.0522         0.215               0.0
#
#    liveness  valence    tempo  time_signature
# 0    0.3110    0.602  160.018               4
# 1    0.9200    0.706  158.054               4
# 2    0.6890    0.721  159.918               4
# 3    0.1100    0.728  167.922               4
# 4    0.0827    0.745  149.969               4
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Renomeando as colunas para português

# %%
df_musicas.columns
# Out:
# Index(['track_id', 'track_name', 'artist_name', 'artist_genres', 'album_name',
#        'artist_id', 'popularity', 'duration_ms', 'explicit', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df_musicas.rename(columns={'track_id': 'id_da_faixa',
                        'track_name': 'nome_da_faixa',
                        'artist_name': 'nome_do_artista',
                        'artist_genres': 'generos_do_artista',
                        'album_name': 'nome_do_album',
                        'artist_id': 'id_do_artista',
                        'popularity': 'popularidade',
                        'duration_ms': 'duracao_ms',
                        'explicit': 'explicita',
                        'danceability': 'dançabilidade',
                        'energy': 'energia',
                        'key': 'chave',
                        'loudness': 'volume',
                        'mode': 'modo',
                        'speechiness': 'fala',
                        'acousticness': 'acusticidade',
                        'instrumentalness': 'instrumentalidade',
                        'liveness': 'vivacidade',
                        'valence': 'valencia',
                        'tempo': 'tempo',
                        'time_signature': 'assinatura_tempo'}, inplace=True)

# %% [markdown]
# ### Excluindo as linhas duplicadas

# %%
df_musicas.duplicated().sum()
# Out:
# 1524

# %%
df_musicas.shape
# Out:
# (8168, 21)

# %%
df_musicas = df_musicas.drop_duplicates(keep='last')
df_musicas.shape
# Out:
# (6644, 21)

# %% [markdown]
# ### Criação de uma nova coluna para a duração das músicas em minutos

# %%
df_musicas['duracao_ms'].dtype
# Out:
# dtype('int64')

# %%
df_musicas['duracao_min'] = pd.to_datetime(df_musicas['duracao_ms'], unit='ms').dt.strftime('%M:%S')
df_musicas.head()
# Out:
#               id_da_faixa          nome_da_faixa nome_do_artista  \
# 0  4uqJelb9THHmJ3OCohg4ZJ           Nosso Quadro     Ana Castela
# 1  0SCMVUZ21uYYB8cc0ScfbV  Bombonzinho - Ao Vivo     Ana Castela
# 2  0redQHBfejmPUhonR5ppGC              Duas Três     Ana Castela
# 3  7sopDXkuzXtHt8AQpdBxmT            DONA DE MIM     Ana Castela
# 4  5y7yYXNSsT89A27DQxbmUL               Covardia     Ana Castela
#
#                          generos_do_artista                 nome_do_album  \
# 0  ['agronejo', 'funk rj', 'sertanejo pop']                  Nosso Quadro
# 1  ['agronejo', 'funk rj', 'sertanejo pop']  Let's Bora, Vol. 2 (Ao Vivo)
# 2  ['agronejo', 'funk rj', 'sertanejo pop']                     Duas Três
# 3  ['agronejo', 'funk rj', 'sertanejo pop']                   DONA DE MIM
# 4  ['agronejo', 'funk rj', 'sertanejo pop']                      Covardia
#
#             id_do_artista  popularidade  duracao_ms  explicita  dançabilidade  \
# 0  2CKOmarVWvWqkNWUatHCex            84      173698      False          0.691
# 1  2CKOmarVWvWqkNWUatHCex            79      154701      False          0.654
# 2  2CKOmarVWvWqkNWUatHCex            87      156942      False          0.656
# 3  2CKOmarVWvWqkNWUatHCex            84      145091      False          0.680
# 4  2CKOmarVWvWqkNWUatHCex            84      150863      False          0.656
#
#    ...  volume  modo    fala  acusticidade  instrumentalidade  vivacidade  \
# 0  ...  -4.821     1  0.1950         0.338                0.0      0.3110
# 1  ...  -3.672     1  0.0548         0.300                0.0      0.9200
# 2  ...  -3.746     0  0.2010         0.574                0.0      0.6890
# 3  ...  -4.726     1  0.2340         0.437                0.0      0.1100
# 4  ...  -3.316     1  0.0522         0.215                0.0      0.0827
#
#    valencia    tempo  assinatura_tempo  duracao_min
# 0     0.602  160.018                 4        02:53
# 1     0.706  158.054                 4        02:34
# 2     0.721  159.918                 4        02:36
# 3     0.728  167.922                 4        02:25
# 4     0.745  149.969                 4        02:30
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Primeiras análises

# %%
df_musicas['id_da_faixa'].value_counts() > 1
# Out:
# 7lzfMZak2HjNPXXSxksjPB     True
# 4L9XGAYgA3Q04qecyjV7iB     True
# 7qoIhutxU269Zqo9PG5IOj     True
# 2r4zhMrN1cQEXNWNG2SkXW     True
# 2FGhB10Gon36GgFcOTMQEW     True
#                           ...
# 4Bo6FwC7Oe9zywSZc6q7hO    False
# 7BXW1QCg56yzEBV8pW8pah    False
# 4xYlpJPENfM4DT0rUYFqSP    False
# 38jy6kRlPt8z1GUS9WXeNh    False
# 3T07vZgzWFs953T7F3XSsv    False
# Name: id_da_faixa, Length: 5737, dtype: bool

# %%
df_musicas.loc[df_musicas['id_da_faixa'] == '7lzfMZak2HjNPXXSxksjPB']
# Out:
#                 id_da_faixa                  nome_da_faixa nome_do_artista  \
# 340  7lzfMZak2HjNPXXSxksjPB  Camarão Que Dorme a Onda Leva   Jorge Ben Jor
# 371  7lzfMZak2HjNPXXSxksjPB  Camarão Que Dorme a Onda Leva          Lenine
# 273  7lzfMZak2HjNPXXSxksjPB  Camarão Que Dorme a Onda Leva         Alcione
# 492  7lzfMZak2HjNPXXSxksjPB  Camarão Que Dorme a Onda Leva          Frejat
# 461  7lzfMZak2HjNPXXSxksjPB  Camarão Que Dorme a Onda Leva   Beth Carvalho
# 398  7lzfMZak2HjNPXXSxksjPB  Camarão Que Dorme a Onda Leva      Maria Rita
# 184  7lzfMZak2HjNPXXSxksjPB  Camarão Que Dorme a Onda Leva        Péricles
# 360  7lzfMZak2HjNPXXSxksjPB  Camarão Que Dorme a Onda Leva          Djavan
# 208  7lzfMZak2HjNPXXSxksjPB  Camarão Que Dorme a Onda Leva       Mumuzinho
# 380  7lzfMZak2HjNPXXSxksjPB  Camarão Que Dorme a Onda Leva         Emicida
# 0    7lzfMZak2HjNPXXSxksjPB  Camarão Que Dorme a Onda Leva  Zeca Pagodinho
# 335  7lzfMZak2HjNPXXSxksjPB  Camarão Que Dorme a Onda Leva    Arlindo Cruz
#
#                                     generos_do_artista  \
# 340  ['bossa nova', 'manguebeat', 'mpb', 'samba', '...
# 371  ['bossa nova', 'brazilian rock', 'manguebeat',...
# 273  ['mpb', 'musica maranhense', 'pagode', 'pagode...
# 492                ['mpb', 'rock nacional brasileiro']
# 461  ['bossa nova', 'mpb', 'pagode', 'partido alto'...
# 398           ['bossa nova', 'mpb', 'pagode', 'samba']
# 184                          ['pagode', 'pagode novo']
# 360                         ['mpb', 'musica alagoana']
# 208                          ['pagode', 'pagode novo']
# 380  ['afrofuturismo brasileiro', 'brazilian hip ho...
# 0    ['mpb', 'pagode', 'partido alto', 'samba', 'sa...
# 335          ['mpb', 'pagode', 'pagode novo', 'samba']
#
#                         nome_do_album           id_do_artista  popularidade  \
# 340  Sambabook Zeca Pagodinho, Vol. 2  5JYtpnUKxAzXfHEYpOeeit            64
# 371  Sambabook Zeca Pagodinho, Vol. 2  4YLBdrR3DVSMncm785NH6C            64
# 273  Sambabook Zeca Pagodinho, Vol. 2  0hPar6ePAELiu9rYMdvMEo            64
# 492  Sambabook Zeca Pagodinho, Vol. 2  3WVjDclrbHsxjxhiOqHdnw            64
# 461  Sambabook Zeca Pagodinho, Vol. 2  56TkPi7rpmU8jTpkcK7FY3            64
# 398  Sambabook Zeca Pagodinho, Vol. 2  1C8UBSZs5rOPfxuxTMS6OI            64
# 184  Sambabook Zeca Pagodinho, Vol. 2  6gEzJZrbm0F4ihvE9iXR9z            64
# 360  Sambabook Zeca Pagodinho, Vol. 2  5rrmaoBXZ7Jcs4Qb77j0YA            64
# 208  Sambabook Zeca Pagodinho, Vol. 2  34dfPo3Zi55yM6oV46q4y7            64
# 380  Sambabook Zeca Pagodinho, Vol. 2  2d9LRvQJnAXRijqIJDDs2K            64
# 0    Sambabook Zeca Pagodinho, Vol. 2  3qZ2n5keOAat1SoF6bHwmb            64
# 335  Sambabook Zeca Pagodinho, Vol. 2  096an3uS6ZaK2XySae6SqP            64
#
#      duracao_ms  explicita  dançabilidade  ...  volume  modo    fala  \
# 340      168948      False          0.723  ...  -6.694     1  0.0802
# 371      168948      False          0.723  ...  -6.694     1  0.0802
# 273      168948      False          0.723  ...  -6.694     1  0.0802
# 492      168948      False          0.723  ...  -6.694     1  0.0802
# 461      168948      False          0.723  ...  -6.694     1  0.0802
# 398      168948      False          0.723  ...  -6.694     1  0.0802
# 184      168948      False          0.723  ...  -6.694     1  0.0802
# 360      168948      False          0.723  ...  -6.694     1  0.0802
# 208      168948      False          0.723  ...  -6.694     1  0.0802
# 380      168948      False          0.723  ...  -6.694     1  0.0802
# 0        168948      False          0.723  ...  -6.694     1  0.0802
# 335      168948      False          0.723  ...  -6.694     1  0.0802
#
#      acusticidade  instrumentalidade  vivacidade  valencia    tempo  \
# 340         0.313                0.0       0.052     0.739  106.359
# 371         0.313                0.0       0.052     0.739  106.359
# 273         0.313                0.0       0.052     0.739  106.359
# 492         0.313                0.0       0.052     0.739  106.359
# 461         0.313                0.0       0.052     0.739  106.359
# 398         0.313                0.0       0.052     0.739  106.359
# 184         0.313                0.0       0.052     0.739  106.359
# 360         0.313                0.0       0.052     0.739  106.359
# 208         0.313                0.0       0.052     0.739  106.359
# 380         0.313                0.0       0.052     0.739  106.359
# 0           0.313                0.0       0.052     0.739  106.359
# 335         0.313                0.0       0.052     0.739  106.359
#
#      assinatura_tempo  duracao_min
# 340                 4        02:48
# 371                 4        02:48
# 273                 4        02:48
# 492                 4        02:48
# 461                 4        02:48
# 398                 4        02:48
# 184                 4        02:48
# 360                 4        02:48
# 208                 4        02:48
# 380                 4        02:48
# 0                   4        02:48
# 335                 4        02:48
#
# [12 rows x 22 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
conta_track_id = df_musicas['id_da_faixa'].unique()
conta_track_id.size
# Out:
# 5737

# %% [markdown]
# ### Verificando os valores de algumas colunas

# %%
df_musicas['assinatura_tempo'].value_counts()
# Out:
# 4    5928
# 3     351
# 5     347
# 1      15
# 0       3
# Name: assinatura_tempo, dtype: int64

# %%
df_musicas['assinatura_tempo'].plot(kind='hist', figsize=(14, 6), color='green')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_musicas['popularidade'].mean()
# Out:
# 61.401414810355206

# %%
df_musicas['popularidade'].plot(kind='density', figsize=(14, 6), c='green')

# Adicionando linha na média
median_popularidade = df_musicas['popularidade'].median()
mean_popularidade = df_musicas['popularidade'].mean()
plt.axvline(mean_popularidade, color='red', linestyle='--', label='Média')
plt.axvline(median_popularidade, color='blue', label='Mediana')
plt.xlim(0, 100)  # Definindo os limites do eixo x
plt.legend()  # Mostrar a legenda
plt.title("Densidade da popularidade")
plt.show()

# %%
df_musicas['modo'].value_counts()
# Out:
# 1    3702
# 0    2942
# Name: modo, dtype: int64

# %%
explode = (0.1, 0)  # Define o afastamento das fatias
cores = ['#FF4040', '#6495ED'] # Define as cores das fatias

df_musicas['modo'].value_counts().plot.pie(autopct='%1.1f%%', explode=explode, colors=cores)
# Out:
# <Axes: ylabel='modo'>

# %%
df_musicas['explicita'].value_counts()
# Out:
# False    4545
# True     2099
# Name: explicita, dtype: int64

# %%
explode = (0.1, 0)  # Define o afastamento das fatias
cores = ['#FF4040', '#00FF00']  # Define as cores das fatias

df_musicas['explicita'].value_counts().plot.pie(autopct='%1.1f%%', explode=explode, colors=cores)
# Out:
# <Axes: ylabel='explicita'>

# %%
df_musicas['chave'].value_counts()
# Out:
# 1     709
# 7     697
# 0     681
# 11    658
# 9     621
# 2     601
# 4     543
# 5     533
# 6     501
# 10    414
# 8     411
# 3     275
# Name: chave, dtype: int64

# %%
df_musicas['chave'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='chave'>

# %% [markdown]
# ## Classificando os dados

# %% [markdown]
# ### Músicas por Artistas

# %%
df_tracksbyArtists = df_musicas[['id_do_artista','nome_do_artista']].value_counts()

print(df_musicas['id_do_artista'].unique().size, 'artistas no total.')

display(df_tracksbyArtists)
# Out:
# 671 artistas no total.
# id_do_artista           nome_do_artista
# 3nfVTPYDnppERKGCRS4vim  PJ HOUDINI         11
# 3GBPw9NK25X1Wt2OUvOwY3  Jack Johnson       11
# 0kjGPGtoyKwKVOZAKmv5K6  GIULIA BE          11
# 47uyFQHOD02S0lj9ptRpoB  Felipe Araújo      11
# 56TkPi7rpmU8jTpkcK7FY3  Beth Carvalho      10
#                                            ..
# 4CjwZ3c0XNrtf2JkXV0Ss6  Mc Lzyn             4
# 5L1lO4eRHmJ7a0Q6csE5cT  LISA                4
# 6DsMACWhJ5AgWLkZA2f5BV  JHXW                3
# 03evdtQP9vcuqdDU6hOluN  Nick Nash           3
# 2Pel0jsoeCdLst2bxzykQJ  dvrkness13          2
# Length: 671, dtype: int64

# %% [markdown]
# ### Músicas com a maior popularidade

# %%
df_toptracks = df_musicas.sort_values('popularidade',ascending = False).head(100)

df_toptracks_view = df_toptracks[['nome_da_faixa', 'nome_do_artista', 'popularidade']].copy()

df_toptracks_view.reset_index()[['nome_da_faixa', 'nome_do_artista','popularidade']]
# Out:
#                                   nome_da_faixa   nome_do_artista  \
# 0                             Cupid - Twin Ver.       FIFTY FIFTY
# 1                                      Daylight     David Kushner
# 2                                           TQG           Shakira
# 3                                          BESO    Rauw Alejandro
# 4                                          BESO           ROSALÍA
# ..                                          ...               ...
# 95               Fair Trade (with Travis Scott)      Travis Scott
# 96                     Something Just Like This  The Chainsmokers
# 97  I Like You (A Happier Song) (with Doja Cat)       Post Malone
# 98       Conexões de Máfia (feat. Rich The Kid)             Matuê
# 99  I Like You (A Happier Song) (with Doja Cat)          Doja Cat
#
#     popularidade
# 0             98
# 1             97
# 2             96
# 3             96
# 4             96
# ..           ...
# 95            87
# 96            87
# 97            87
# 98            87
# 99            87
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Artistas com a maior popularidade

# %%
# Assuming your dataframe is named 'df' with columns 'artist' and 'popularity'
df_grouped_artist = df_musicas.groupby(['id_do_artista', 'nome_do_artista'])['popularidade'].sum().reset_index()

# Sort the dataframe based on the sum of popularity in descending order
df_artist_sorted = df_grouped_artist.sort_values(by='popularidade', ascending=False)

# Display the most popular artists
most_popular_artists = df_artist_sorted[['id_do_artista', 'nome_do_artista']].reset_index()[['id_do_artista', 'nome_do_artista']]
most_popular_artists.head(100)
# Out:
#              id_do_artista  nome_do_artista
# 0   1Xyo4u8uXC1ZmMpatF05PJ       The Weeknd
# 1   4gzpq5DPGxSnKTe4SA8HAU         Coldplay
# 2   0iEtIxbK0KxaSlF7G42ZOp     Metro Boomin
# 3   1URnnhqYAYcrqrcwql10ft        21 Savage
# 4   6KImCVD70vtIoJWnq6nGn3     Harry Styles
# ..                     ...              ...
# 95  4tZwfgrHOc3mvqYlEYSvVi        Daft Punk
# 96  7jy3rLJdDQY21OgRLCZ9sD     Foo Fighters
# 97  5LfGQac0EIXyAN8aUwmNAQ    The Offspring
# 98  4SpbR6yFEvexJuaBpgAU5p      LE SSERAFIM
# 99  1yxSLGMDHlW21z4YXirZDS  Black Eyed Peas
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Gêneros mais populares (baseado no genero dos artistas)

# %%
df_grouped_genres = df_musicas.groupby('generos_do_artista')['popularidade'].sum().reset_index()

# Sort the dataframe based on the sum of popularity in descending order
df_genres_sorted = df_grouped_genres.sort_values(by='popularidade', ascending=False)

# Display the most popular artists
most_popular_genres = df_genres_sorted[['generos_do_artista', 'popularidade']].reset_index()[['generos_do_artista', 'popularidade']]

most_popular_genres.head(100)
# Out:
#                       generos_do_artista  popularidade
# 0                                     []         29195
# 1                    ['trap brasileiro']         20683
# 2                   ['brazilian gospel']          9545
# 3              ['pagode', 'pagode novo']          6254
# 4                            ['arrocha']          5907
# ..                                   ...           ...
# 95                    ['pop', 'pop r&b']           804
# 96  ['canadian pop', 'pop', 'viral pop']           804
# 97       ['art pop', 'dance pop', 'pop']           804
# 98                  ['pop', 'viral pop']           804
# 99                        ['r&b', 'rap']           801
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Músicas com as maiores durações

# %%
df_longestTracks = df_musicas[["nome_da_faixa","nome_do_artista", "duracao_min", "duracao_ms"]].sort_values(by="duracao_min",ascending=False)[:20]

df_longestTracks = df_longestTracks.reset_index()[['nome_da_faixa','nome_do_artista', 'duracao_min', 'duracao_ms']]
df_longestTracks = df_longestTracks.drop_duplicates(keep='last')
df_longestTracks
# Out:
#                                         nome_da_faixa        nome_do_artista  \
# 0                          Bloco Do Polly 2.0 Hitmado            Oh Polêmico
# 1                           Poetas no Topo 3.3, Pt. 1          Bob do Contra
# 2                           Poetas no Topo 3.3, Pt. 1                  Dk 47
# 3   Chato Pa Carai / Recaída / Vai Me Dando Corda ...               Vou Zuar
# 4                                Seu Amor Me Persegue                   AMÉM
# 5               Shine On You Crazy Diamond (Pts. 1-5)             Pink Floyd
# 6                                      Bloco Do Polly            Oh Polêmico
# 7                                   Love Acústico 2.0           Belle Kaffer
# 8                         Hit do Ano - O Peso da Luta         MC Leozinho ZS
# 9                         Hit do Ano - O Peso da Luta               MC Marks
# 10                        Hit do Ano - O Peso da Luta            Mc Kelvinho
# 11                        Hit do Ano - O Peso da Luta  MC Neguinho do Kaxeta
# 12               Poesia Acústica #5: Teu Popô - Remix          Luccas Carlos
# 13               Poesia Acústica #5: Teu Popô - Remix               Chris MC
# 14                                     Em Teus Braços       Laura Souguellis
# 15                                       Bloco Putetê            Oh Polêmico
# 16                      Nada Que o Teu Amor Não Possa       Laura Souguellis
# 17  Separação / Fatalmente / Como Nunca Amei Ningu...               Vou Zuar
# 18                               SET Charles Do Bronx              TrapLaudo
# 19                      Poesia Acústica 10: Recomeçar               LUDMILLA
#
#    duracao_min  duracao_ms
# 0        30:31     1831455
# 1        19:07     1147406
# 2        19:07     1147406
# 3        18:05     1085565
# 4        17:15     1035895
# 5        13:31      811077
# 6        13:07      787725
# 7        13:06      786358
# 8        12:24      744727
# 9        12:24      744727
# 10       12:24      744727
# 11       12:24      744727
# 12       12:17      737704
# 13       12:17      737704
# 14       12:15      735253
# 15       12:10      730090
# 16       12:08      728829
# 17       11:56      716236
# 18       11:27      687853
# 19       11:22      682816

# %%
sns.barplot(x="duracao_ms", y="nome_da_faixa", data= df_longestTracks, color = 'green')
plt.title("5 músicas mais longas")
plt.show()

# %% [markdown]
# ### Músicas com as menores durações

# %%
df_shortTracks = df_musicas[['nome_da_faixa','nome_do_artista', 'duracao_min', 'duracao_ms']].sort_values(by="duracao_min",ascending=True)[:20]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa','nome_do_artista', 'duracao_min', 'duracao_ms']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                                     nome_da_faixa    nome_do_artista  \
# 0                      Bedtime White Noise Melody  Sleeping Tortoise
# 1                        White Noise Piano Melody  Sleeping Tortoise
# 2                         White Noise Calm Melody  Sleeping Tortoise
# 3                   White Noise Baby Sleep Melody  Sleeping Tortoise
# 4                         Gentle Piano Baby Sleep  Sleeping Tortoise
# 5                             Soothing Baby Sleep  Sleeping Tortoise
# 6                      Relaxing Baby Sleep Melody  Sleeping Tortoise
# 7                              Calming Baby Sleep  Sleeping Tortoise
# 8                  Calming White Noise Baby Sleep  Sleeping Tortoise
# 9                             Peaceful Baby Sleep  Sleeping Tortoise
# 10                   Introduction to Sleep Babies          Nana Bebê
# 11                Little Stars Shining in the Sky          Nana Bebê
# 12  Brilha Brilha Estrelinha (Piano Instrumental)          Nana Bebê
# 13                  The Peace That the Soul Needs          Nana Bebê
# 14                            Intro Brasileirinha          Puterrier
# 15                              Clearing the Mind          Nana Bebê
# 16         Sobre O Amor E Seu Trabalho Silencioso                Céu
# 17                 A Tonga Da Mironga Do Kabuletê           Toquinho
# 18                                 hotline (edit)      Billie Eilish
# 19                                      LIE DOWN!              NUEKI
#
#    duracao_min  duracao_ms
# 0        00:32       32000
# 1        00:32       32000
# 2        00:32       32000
# 3        00:32       32000
# 4        00:32       32000
# 5        00:32       32000
# 6        00:32       32000
# 7        00:32       32000
# 8        00:32       32000
# 9        00:32       32000
# 10       00:38       38571
# 11       00:40       40928
# 12       00:43       43889
# 13       00:44       44785
# 14       00:47       47647
# 15       00:47       47571
# 16       00:56       56105
# 17       01:00       60600
# 18       01:00       60719
# 19       01:00       60000

# %% [markdown]
# ### Músicas com a maior energia

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","energia", "volume"]].sort_values(by="energia",ascending=False)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'energia', 'volume']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                                        nome_da_faixa     nome_do_artista  \
# 0  Barulho de Chuva para Dormir Profundamente, Pt...    Barulho De Chuva
# 1                      The Rain Dances on a Tin Roof  Medicina Relaxante
# 2                 É o Antares Melhor Baile da Cidade         MC Flavinho
# 3    Eu Sou a Mc Pipokinha - Tenho Pircing na Xereca               MC MN
# 4    Eu Sou a Mc Pipokinha - Tenho Pircing na Xereca        MC Pipokinha
#
#    energia  volume
# 0    1.000 -23.480
# 1    0.999 -22.224
# 2    0.998  -1.009
# 3    0.997   1.218
# 4    0.997   1.218

# %% [markdown]
# ### Músicas com a menor energia

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","energia", "volume"]].sort_values(by="energia",ascending=True)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'energia', 'volume']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                      nome_da_faixa          nome_do_artista   energia  volume
# 0                Ruido Branco Bebe       Medicina Relaxante  0.000019  -9.879
# 1                     Ruido Branco       Medicina Relaxante  0.000019  -9.954
# 2                Clearing the Mind                Nana Bebê  0.000690 -18.860
# 3  Little Stars Shining in the Sky                Nana Bebê  0.002150 -18.833
# 4           Estrellita Dónde Estás  Wolfgang Amadeus Mozart  0.002600 -29.033

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Músicas mais dançaveis

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","dançabilidade"]].sort_values(by="dançabilidade",ascending=False)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'dançabilidade']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                                  nome_da_faixa nome_do_artista  dançabilidade
# 0                           Botadinha Saliente    MC Rogerinho          0.985
# 1                                      Red Dot       Yunk Vino          0.982
# 2                                      Red Dot     Caio Passos          0.982
# 3                                      Red Dot      Labbel Rec          0.982
# 4  Que Se Foda a Porra Toda (feat. Mc Mr. Bim)           Dj Tk          0.981

# %% [markdown]
# ### Músicas menos dançaveis

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","dançabilidade"]].sort_values(by="dançabilidade",ascending=True)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'dançabilidade']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                                        nome_da_faixa          nome_do_artista  \
# 0                                       Ruido Branco       Medicina Relaxante
# 1                                  Ruido Branco Bebe       Medicina Relaxante
# 2  Requiem in D Minor, K. 626: Sequence: VI. Lacr...  Wolfgang Amadeus Mozart
# 3                                Peaceful Baby Sleep        Sleeping Tortoise
# 4                                Soothing Baby Sleep        Sleeping Tortoise
#
#    dançabilidade
# 0         0.0000
# 1         0.0000
# 2         0.0690
# 3         0.0745
# 4         0.0934

# %% [markdown]
# ### Músicas com mais fala

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","fala"]].sort_values(by="fala",ascending=False)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'fala']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                 nome_da_faixa       nome_do_artista   fala
# 0                   Nômade IV         Yago Oproprio  0.930
# 1  Pede pra Botar Que Eu Boto    DJ Ws da Igrejinha  0.902
# 2           De Treta Em Treta               MC Caja  0.899
# 3           Nois É Maloqueiro  Mc Bruninho da Praia  0.896
# 4                     Mec Mec              DJ Cayoo  0.892

# %% [markdown]
# ### Músicas com menos fala

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","fala"]].sort_values(by="fala",ascending=True)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'fala']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                nome_da_faixa     nome_do_artista    fala
# 0          Ruido Branco Bebe  Medicina Relaxante  0.0000
# 1               Ruido Branco  Medicina Relaxante  0.0000
# 2                 Folha Seca       Amado Batista  0.0230
# 3                    Perfect          Ed Sheeran  0.0232
# 4  Your Body Is a Wonderland          John Mayer  0.0236

# %% [markdown]
# ### Músicas com maior acusticidade

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","acusticidade"]].sort_values(by="acusticidade",ascending=False)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'acusticidade']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                                        nome_da_faixa          nome_do_artista  \
# 0                                  Clearing the Mind                Nana Bebê
# 1      Brilha Brilha Estrelinha (Piano Instrumental)                Nana Bebê
# 2                                        Chuva Chove               Mundo Bita
# 3                                          Boa Noite               Mundo Bita
# 4  Piano Sonata No. 12 in F Major, K. 332: II. Ad...  Wolfgang Amadeus Mozart
#
#    acusticidade
# 0         0.995
# 1         0.995
# 2         0.995
# 3         0.995
# 4         0.995

# %% [markdown]
# ### Músicas com menor acusticidade

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","acusticidade"]].sort_values(by="acusticidade",ascending=True)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'acusticidade']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#         nome_da_faixa     nome_do_artista  acusticidade
# 0   Ruido Branco Bebe  Medicina Relaxante      0.000000
# 1        Ruido Branco  Medicina Relaxante      0.000000
# 2           Under You        Foo Fighters      0.000005
# 3  Whiskey In The Jar           Metallica      0.000006
# 4         Lovers Rock             TV Girl      0.000008

# %% [markdown]
# ### Músicas com maior instrumentalidade

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","instrumentalidade"]].sort_values(by="instrumentalidade",ascending=False)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'instrumentalidade']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                               nome_da_faixa     nome_do_artista  \
# 0                Bedtime White Noise Melody   Sleeping Tortoise
# 1               Hair Dryer [Non-Stationary]  Medicina Relaxante
# 2                       Soothing Baby Sleep   Sleeping Tortoise
# 3                 The Gentlest Thunderstorm  Medicina Relaxante
# 4  Barulho de Chuva Super Relaxante, Pt. 04    Barulho De Chuva
#
#    instrumentalidade
# 0              0.999
# 1              0.994
# 2              0.992
# 3              0.992
# 4              0.991

# %% [markdown]
# ### Músicas com menor instrumentalidade

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","instrumentalidade"]].sort_values(by="instrumentalidade",ascending=True)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'instrumentalidade']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                          nome_da_faixa nome_do_artista  instrumentalidade
# 0                         Nosso Quadro     Ana Castela                0.0
# 1                         Vou Festejar      Maria Rita                0.0
# 2        Camarão Que Dorme a Onda Leva      Maria Rita                0.0
# 3  Purple Lamborghini (with Rick Ross)        Skrillex                0.0
# 4                      Make It Bun Dem        Skrillex                0.0

# %% [markdown]
# ### Músicas com maior vivacidade

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","vivacidade"]].sort_values(by="vivacidade",ascending=False)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'vivacidade']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                                        nome_da_faixa nome_do_artista  \
# 0                    Lanterna dos Afogados - Ao Vivo      Maria Gadú
# 1  Quando Fui Chuva / Fim de Tarde / Palpite - Ao...        Marvvila
# 2                                100 Likes - Ao Vivo            Belo
# 3                                       Agora Perdeu       Bom Gosto
# 4                                Sobrenome - Ao vivo         Vitinho
#
#    vivacidade
# 0       0.993
# 1       0.990
# 2       0.989
# 3       0.988
# 4       0.988

# %% [markdown]
# ### Músicas com menor vivacidade

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","vivacidade"]].sort_values(by="vivacidade",ascending=True)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'vivacidade']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                     nome_da_faixa     nome_do_artista  vivacidade
# 0               Ruido Branco Bebe  Medicina Relaxante      0.0000
# 1                    Ruido Branco  Medicina Relaxante      0.0000
# 2                    Ain't It Fun            Paramore      0.0210
# 3  Finesse - Remix; feat. Cardi B             Cardi B      0.0215
# 4                      Hard Times            Paramore      0.0219

# %% [markdown]
# ### Músicas com maior valência

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","valencia"]].sort_values(by="valencia",ascending=False)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'valencia']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#        nome_da_faixa     nome_do_artista  valencia
# 0  Mordidinha Safada           Mc Daniel     0.981
# 1   Parabéns da Xuxa                Xuxa     0.980
# 2        A Baratinha  Galinha Pintadinha     0.979
# 3   Pega o Guanabara     Alanzim Coreano     0.978
# 4      Material Girl             Madonna     0.978

# %% [markdown]
# ### Músicas com menor valência

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","valencia"]].sort_values(by="valencia",ascending=True)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'valencia']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                   nome_da_faixa     nome_do_artista  valencia
# 0  Introduction to Sleep Babies           Nana Bebê       0.0
# 1      White Noise Piano Melody   Sleeping Tortoise       0.0
# 2             Clearing the Mind           Nana Bebê       0.0
# 3                  Ruido Branco  Medicina Relaxante       0.0
# 4             Ruido Branco Bebe  Medicina Relaxante       0.0

# %% [markdown]
# ### Músicas com maior tempo

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","tempo"]].sort_values(by="tempo",ascending=False)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'tempo']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                                      nome_da_faixa nome_do_artista    tempo
# 0                                 Amor de Violeiro   Eduardo Costa  208.500
# 1  Se Me da Eu Vou Ter Que Comer (Slowed + Reverb)     MC Flavinho  207.964
# 2                                 Somethin' Stupid   Frank Sinatra  207.356
# 3                                        Novo Jazz        Orgânico  205.716
# 4                                          Love Me       Lil Tecca  204.132

# %% [markdown]
# ### Músicas com menor tempo

# %%
df_shortTracks = df_musicas[["nome_da_faixa","nome_do_artista","tempo"]].sort_values(by="tempo",ascending=True)[:5]

df_shortTracks = df_shortTracks.reset_index()[['nome_da_faixa', 'nome_do_artista', 'tempo']]
df_shortTracks = df_shortTracks.drop_duplicates(keep='last')
df_shortTracks
# Out:
#                      nome_da_faixa     nome_do_artista   tempo
# 0                     Ruido Branco  Medicina Relaxante   0.000
# 1                Ruido Branco Bebe  Medicina Relaxante   0.000
# 2         Brilha Brilha Estrelinha  Galinha Pintadinha  41.293
# 3             Cheguei No Anonimato               MC PH  45.109
# 4  Trovões e Sons de Chuva, Pt. 02    Barulho De Chuva  49.768

# %% [markdown]
# ## Correlação dos dados

# %% [markdown]
# Verificar a correlação de dados na análise exploratória é importante porque ajuda a entender a relação entre as variáveis em um conjunto de dados. A correlação é uma medida estatística que indica a força e a direção da relação entre duas variáveis.
#
# Ao examinar a correlação, podemos determinar se as variáveis estão positivamente correlacionadas (ou seja, quando uma aumenta, a outra também aumenta), negativamente correlacionadas (quando uma aumenta, a outra diminui) ou não correlacionadas (quando não há relação aparente entre as variáveis).
#
# Além disso, a correlação também ajuda a identificar possíveis problemas com o conjunto de dados, como a presença de outliers ou variáveis altamente correlacionadas, o que pode afetar a precisão dos modelos de análise de dados.

# %%
df_corr = df_musicas.corr(method="pearson")

df_corr
# Out:
# C:\Users\mateu\AppData\Local\Temp\ipykernel_14592\1375236007.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df_musicas.corr(method="pearson")
#                    popularidade  duracao_ms  explicita  dançabilidade  \
# popularidade           1.000000    0.057759  -0.050252      -0.029641
# duracao_ms             0.057759    1.000000  -0.043615      -0.249393
# explicita             -0.050252   -0.043615   1.000000       0.324920
# dançabilidade         -0.029641   -0.249393   0.324920       1.000000
# energia                0.074732   -0.095822  -0.085578       0.054999
# chave                 -0.027843    0.007261   0.012675       0.025444
# volume                 0.078772   -0.074379   0.118253       0.244976
# modo                  -0.028828   -0.028977  -0.141801      -0.121618
# fala                  -0.075520   -0.022465   0.441004       0.261817
# acusticidade          -0.198317   -0.023432  -0.096495      -0.132582
# instrumentalidade     -0.099605   -0.077645  -0.061287      -0.116906
# vivacidade            -0.055120    0.008691  -0.214087      -0.246227
# valencia              -0.064202   -0.185574  -0.001741       0.392224
# tempo                 -0.018539    0.000407  -0.041786      -0.028114
# assinatura_tempo       0.009735    0.055308   0.114083       0.157615
#
#                     energia     chave    volume      modo      fala  \
# popularidade       0.074732 -0.027843  0.078772 -0.028828 -0.075520
# duracao_ms        -0.095822  0.007261 -0.074379 -0.028977 -0.022465
# explicita         -0.085578  0.012675  0.118253 -0.141801  0.441004
# dançabilidade      0.054999  0.025444  0.244976 -0.121618  0.261817
# energia            1.000000  0.030812  0.652955  0.002077 -0.116636
# chave              0.030812  1.000000  0.020846 -0.092951  0.035644
# volume             0.652955  0.020846  1.000000 -0.039484  0.042656
# modo               0.002077 -0.092951 -0.039484  1.000000 -0.163934
# fala              -0.116636  0.035644  0.042656 -0.163934  1.000000
# acusticidade      -0.408147 -0.012324 -0.270752  0.050809 -0.018286
# instrumentalidade -0.110237  0.001797 -0.373362  0.046092 -0.068041
# vivacidade         0.257792 -0.014334  0.056693  0.106772 -0.165287
# valencia           0.336159  0.035692  0.278741 -0.055892  0.093510
# tempo              0.160985 -0.003462  0.115534  0.011889 -0.024614
# assinatura_tempo   0.027947  0.005867  0.101416 -0.063271  0.166940
#
#                    acusticidade  instrumentalidade  vivacidade  valencia  \
# popularidade          -0.198317          -0.099605   -0.055120 -0.064202
# duracao_ms            -0.023432          -0.077645    0.008691 -0.185574
# explicita             -0.096495          -0.061287   -0.214087 -0.001741
# dançabilidade         -0.132582          -0.116906   -0.246227  0.392224
# energia               -0.408147          -0.110237    0.257792  0.336159
# chave                 -0.012324           0.001797   -0.014334  0.035692
# volume                -0.270752          -0.373362    0.056693  0.278741
# modo                   0.050809           0.046092    0.106772 -0.055892
# fala                  -0.018286          -0.068041   -0.165287  0.093510
# acusticidade           1.000000           0.078787    0.066463  0.024145
# instrumentalidade      0.078787           1.000000   -0.029662 -0.123788
# vivacidade             0.066463          -0.029662    1.000000  0.043650
# valencia               0.024145          -0.123788    0.043650  1.000000
# tempo                 -0.050919          -0.039159    0.058129  0.098264
# assinatura_tempo      -0.041656          -0.036874   -0.041433  0.093966
#
#                       tempo  assinatura_tempo
# popularidade      -0.018539          0.009735
# duracao_ms         0.000407          0.055308
# explicita         -0.041786          0.114083
# dançabilidade     -0.028114          0.157615
# energia            0.160985          0.027947
# chave             -0.003462          0.005867
# volume             0.115534          0.101416
# modo               0.011889         -0.063271
# fala              -0.024614          0.166940
# acusticidade      -0.050919         -0.041656
# instrumentalidade -0.039159         -0.036874
# vivacidade         0.058129         -0.041433
# valencia           0.098264          0.093966
# tempo              1.000000         -0.032102
# assinatura_tempo  -0.032102          1.000000

# %%
plt.figure(figsize=(16, 5))
sns.heatmap(df_corr, annot=True, fmt=".1g", cmap="Greens")
plt.title("Correlação entre as variáveis")
plt.show()

# %% [markdown]
# #### Correlação entre acusticidade e energia

# %% [markdown]
# Primeiro extraímos os valores de x e y do DataFrame df_musicas. Em seguida, usamos a função np.polyfit() para calcular os coeficientes da linha linear que melhor se ajustam aos pontos de dados. Em seguida, criamos uma função de linha usando np.poly1d(). Por fim, usamos plt.plot() para traçar a linha usando os valores de x e a função de linha.

# %%
df_musicas.plot(kind='scatter', x='acusticidade', y='energia', figsize=(8, 6), c='green')

# Adicionando linha linear
x = df_musicas['acusticidade']
y = df_musicas['energia']
coefficients = np.polyfit(x, y, 1)
line = np.poly1d(coefficients)
plt.plot(x, line(x), color='red')
plt.title("Correlação entre acusticidade e energia")
plt.show()

# %% [markdown]
# #### Correlação entre energia e volume

# %%
df_musicas.plot(kind='scatter', x='volume', y='energia', figsize=(8, 6), c='green')

# Adicionando linha linear
x = df_musicas['volume']
y = df_musicas['energia']
coefficients = np.polyfit(x, y, 1)
line = np.poly1d(coefficients)
plt.plot(x, line(x), color='red')
plt.title("Correlação entre energia e volume")
plt.show()

# %% [markdown]
# # Dataframe dos Usuários

# %% [markdown]
# ## Juntando os arquivos dos dataframes

# %%
diretorio = "./DataFrames/Usuários"
arquivos = [arquivo for arquivo in os.listdir(diretorio) if not arquivo.startswith('.')] #Ignora arquivos escondidos

df_usuarios = pd.DataFrame()

for arquivo in arquivos:
    data_atual = pd.read_csv(diretorio+"/"+arquivo)
    data_atual['Usuário'] = arquivo[:-4]
    df_usuarios = pd.concat([df_usuarios, data_atual])

# %%
df_usuarios
# Out:
#     Unnamed: 0                track_id                track_name  \
# 0            0  0JSux25Te5HYMSr2D64d02            Levanta e Anda
# 1            1  28M9CSVpZ8x526MKvb1U2W          Foco, Força E Fé
# 2            2  4S3zWMCOGI5k61u78QTGWR  Sorrisos (feat. Lourena)
# 3            3  3QLk7GwoJ1k08idUqahbBl                  Acredita
# 4            4  63400Pm7x5Awe4NH82oRYe                       War
# ..         ...                     ...                       ...
# 15          15  4Wu62DoQg1ECGlDKDfo30R                      Hero
# 16          16  1v1oIWf2Xgh54kIWuKsDf6                   Runaway
# 17          17  4Bce8zih5vey2GVnAbOQu6                 Mad World
# 18          18  5E30LdtzQTGqRvNd7l6kG5              Daddy Issues
# 19          19  1s70cjkrdj9lpEeQQlmS9l                Die a King
#
#              artist_name                                      artist_genres  \
# 0                Emicida  ['afrofuturismo brasileiro', 'brazilian hip ho...
# 1                Projota  ['brazilian hip hop', 'funk carioca', 'pop nac...
# 2                 L7NNON  ['funk rj', 'pop rap brasileiro', 'trap brasil...
# 3   MC Paulin da Capital               ['funk consciente', 'funk paulista']
# 4             Filipe Ret                             ['pop rap brasileiro']
# ..                   ...                                                ...
# 15         Martin Garrix  ['dutch edm', 'edm', 'pop', 'pop dance', 'prog...
# 16                AURORA                       ['art pop', 'norwegian pop']
# 17                Bisken                                                 []
# 18     The Neighbourhood  ['modern alternative rock', 'modern rock', 'po...
# 19           iamjakehill                                        ['sad rap']
#
#    Usuário
# 0     Caio
# 1     Caio
# 2     Caio
# 3     Caio
# 4     Caio
# ..     ...
# 15   Pedro
# 16   Pedro
# 17   Pedro
# 18   Pedro
# 19   Pedro
#
# [80 rows x 6 columns]

# %% [markdown]
# ## Análise exploratória de dados

# %% [markdown]
# ### Informações sobre as colunas

# %%
df_usuarios.shape
# Out:
# (80, 6)

# %%
df_usuarios.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'track_name', 'artist_name', 'artist_genres',
#        'Usuário'],
#       dtype='object')

# %%
df_usuarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     80 non-null     int64
#  1   track_id       80 non-null     object
#  2   track_name     80 non-null     object
#  3   artist_name    80 non-null     object
#  4   artist_genres  80 non-null     object
#  5   Usuário        80 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 4.4+ KB

# %%
df_usuarios.dtypes
# Out:
# Unnamed: 0        int64
# track_id         object
# track_name       object
# artist_name      object
# artist_genres    object
# Usuário          object
# dtype: object

# %%
df_usuarios.dtypes.value_counts()
# Out:
# object    5
# int64     1
# dtype: int64

# %%
df_usuarios.describe()
# Out:
#        Unnamed: 0
# count   80.000000
# mean     9.500000
# std      5.802662
# min      0.000000
# 25%      4.750000
# 50%      9.500000
# 75%     14.250000
# max     19.000000

# %% [markdown]
# ### Verificando se existem valores nulos no dataframe

# %%
df_usuarios.isnull().sum()
# Out:
# Unnamed: 0       0
# track_id         0
# track_name       0
# artist_name      0
# artist_genres    0
# Usuário          0
# dtype: int64

# %% [markdown]
# ### Verificando se existem linhas duplicadas no dataframe

# %%
df_usuarios.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Length: 80, dtype: bool

# %%
df_usuarios.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Tratando o dataframe

# %% [markdown]
# ### Excluindo a coluna "Unnamed: 0"

# %%
df_usuarios = df_usuarios.drop("Unnamed: 0", axis=1)
df_usuarios.head()
# Out:
#                  track_id                track_name           artist_name  \
# 0  0JSux25Te5HYMSr2D64d02            Levanta e Anda               Emicida
# 1  28M9CSVpZ8x526MKvb1U2W          Foco, Força E Fé               Projota
# 2  4S3zWMCOGI5k61u78QTGWR  Sorrisos (feat. Lourena)                L7NNON
# 3  3QLk7GwoJ1k08idUqahbBl                  Acredita  MC Paulin da Capital
# 4  63400Pm7x5Awe4NH82oRYe                       War            Filipe Ret
#
#                                        artist_genres Usuário
# 0  ['afrofuturismo brasileiro', 'brazilian hip ho...    Caio
# 1  ['brazilian hip hop', 'funk carioca', 'pop nac...    Caio
# 2  ['funk rj', 'pop rap brasileiro', 'trap brasil...    Caio
# 3               ['funk consciente', 'funk paulista']    Caio
# 4                             ['pop rap brasileiro']    Caio

# %% [markdown]
# ### Renomeando as colunas para português

# %%
df_usuarios.columns
# Out:
# Index(['track_id', 'track_name', 'artist_name', 'artist_genres', 'Usuário'], dtype='object')

# %%
df_usuarios.rename(columns={'track_id': 'id_da_faixa',
                   'track_name': 'nome_da_faixa',
                   'artist_name': 'nome_do_artista',
                   'artist_genres': 'generos_do_artista',
                   'Usuário': 'usuário'}, inplace=True)

# %%
df_usuarios.head()
# Out:
#               id_da_faixa             nome_da_faixa       nome_do_artista  \
# 0  0JSux25Te5HYMSr2D64d02            Levanta e Anda               Emicida
# 1  28M9CSVpZ8x526MKvb1U2W          Foco, Força E Fé               Projota
# 2  4S3zWMCOGI5k61u78QTGWR  Sorrisos (feat. Lourena)                L7NNON
# 3  3QLk7GwoJ1k08idUqahbBl                  Acredita  MC Paulin da Capital
# 4  63400Pm7x5Awe4NH82oRYe                       War            Filipe Ret
#
#                                   generos_do_artista usuário
# 0  ['afrofuturismo brasileiro', 'brazilian hip ho...    Caio
# 1  ['brazilian hip hop', 'funk carioca', 'pop nac...    Caio
# 2  ['funk rj', 'pop rap brasileiro', 'trap brasil...    Caio
# 3               ['funk consciente', 'funk paulista']    Caio
# 4                             ['pop rap brasileiro']    Caio

# %% [markdown]
# ## Primeiras análises

# %%
df_usuarios['id_da_faixa'].duplicated().value_counts()
# Out:
# False    79
# True      1
# Name: id_da_faixa, dtype: int64

# %%
df_usuarios['id_da_faixa'].value_counts() > 1
# Out:
# 6EtKlIQmGPB9SX8UjDJG5s     True
# 0JSux25Te5HYMSr2D64d02    False
# 17vkpwdNFLE5T1Y4PE3stJ    False
# 07VBqWH6NG8L2ad3l84UKk    False
# 4pzRxLzkLjnqnrOL0VMV5w    False
#                           ...
# 1Fcp74jdEpOohdgPCCGI8f    False
# 7hDVYcQq6MxkdJGweuCtl9    False
# 3nfj9Fdbl30TvcZE9sU0Vx    False
# 0fBSs3fRoh1yJcne77fdu9    False
# 1s70cjkrdj9lpEeQQlmS9l    False
# Name: id_da_faixa, Length: 79, dtype: bool

# %%
df_usuarios.loc[df_usuarios['id_da_faixa'] == '6EtKlIQmGPB9SX8UjDJG5s']
# Out:
#                id_da_faixa nome_da_faixa nome_do_artista  \
# 13  6EtKlIQmGPB9SX8UjDJG5s       Formula        Labrinth
# 0   6EtKlIQmGPB9SX8UjDJG5s       Formula        Labrinth
#
#             generos_do_artista usuário
# 13  ['indie poptimism', 'pop']    Davi
# 0   ['indie poptimism', 'pop']   Pedro

# %%
df_usuarios['generos_do_artista'].value_counts()
# Out:
# []                                                                                  6
# ['modern alternative rock', 'modern rock', 'pop', 'pov: indie']                     4
# ['modern rock', 'pop', 'rock']                                                      3
# ['indie poptimism', 'pop']                                                          2
# ['trap brasileiro', 'trap funk']                                                    2
#                                                                                    ..
# ['gaming edm']                                                                      1
# ['folk-pop', 'modern rock']                                                         1
# ['musica triste brasileira']                                                        1
# ['brazilian hip hop', 'funk carioca', 'pop nacional', 'sertanejo universitario']    1
# ['sad rap']                                                                         1
# Name: generos_do_artista, Length: 61, dtype: int64

# %%
df_usuarios.iloc[0:80]
# Out:
#                id_da_faixa             nome_da_faixa       nome_do_artista  \
# 0   0JSux25Te5HYMSr2D64d02            Levanta e Anda               Emicida
# 1   28M9CSVpZ8x526MKvb1U2W          Foco, Força E Fé               Projota
# 2   4S3zWMCOGI5k61u78QTGWR  Sorrisos (feat. Lourena)                L7NNON
# 3   3QLk7GwoJ1k08idUqahbBl                  Acredita  MC Paulin da Capital
# 4   63400Pm7x5Awe4NH82oRYe                       War            Filipe Ret
# ..                     ...                       ...                   ...
# 15  4Wu62DoQg1ECGlDKDfo30R                      Hero         Martin Garrix
# 16  1v1oIWf2Xgh54kIWuKsDf6                   Runaway                AURORA
# 17  4Bce8zih5vey2GVnAbOQu6                 Mad World                Bisken
# 18  5E30LdtzQTGqRvNd7l6kG5              Daddy Issues     The Neighbourhood
# 19  1s70cjkrdj9lpEeQQlmS9l                Die a King           iamjakehill
#
#                                    generos_do_artista usuário
# 0   ['afrofuturismo brasileiro', 'brazilian hip ho...    Caio
# 1   ['brazilian hip hop', 'funk carioca', 'pop nac...    Caio
# 2   ['funk rj', 'pop rap brasileiro', 'trap brasil...    Caio
# 3                ['funk consciente', 'funk paulista']    Caio
# 4                              ['pop rap brasileiro']    Caio
# ..                                                ...     ...
# 15  ['dutch edm', 'edm', 'pop', 'pop dance', 'prog...   Pedro
# 16                       ['art pop', 'norwegian pop']   Pedro
# 17                                                 []   Pedro
# 18  ['modern alternative rock', 'modern rock', 'po...   Pedro
# 19                                        ['sad rap']   Pedro
#
# [80 rows x 5 columns]
